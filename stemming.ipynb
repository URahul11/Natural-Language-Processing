# %% [markdown]
# <a href="https://colab.research.google.com/github/URahul11/Natural-Language-Processing/blob/main/stemming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

nltk.download('punkt')

nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize

from nltk.stem import PorterStemmer



text="""write anything whatever you want here"""

stemmer=PorterStemmer()

words=word_tokenize (text)

stemmed_words=[stemmer.stem (word) for word in words]

print(stemmed_words)

['write', 'anyth', 'whatev', 'you', 'want', 'here']
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['write', 'anyth', 'whatev', 'you', 'want', 'here']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['write', 'anyth', 'whatev', 'you', 'want', 'here']
