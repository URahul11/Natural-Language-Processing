# %% [markdown]
# <a href="https://colab.research.google.com/github/URahul11/Natural-Language-Processing/blob/main/Porter_Stemmer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.stem import PorterStemmer

nltk.download('punkt_tab')
ps = PorterStemmer()

words = ["program", "programs", "programmer", "programming", "programmed"]
for w in words:
    print(f"{w} -> {ps.stem(w)}")

sentence = "The programmers are programming a new program in Python"
tokenized_words = nltk.word_tokenize(sentence)
print("\nSentence Stemming:")
stemmed_sentence = [ps.stem(w) for w in tokenized_words]
print(" ".join(stemmed_sentence))
# Out:
# program -> program
# programs -> program
# programmer -> programm
# programming -> program
# programmed -> program
#
# Sentence Stemming:
# the programm are program a new program in python
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True
