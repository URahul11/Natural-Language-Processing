# %% [markdown]
# <a href="https://colab.research.google.com/github/URahul11/Natural-Language-Processing/blob/main/random_word_operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import string
import nltk # Corrected 'nitk' to 'nltk'

from nltk.corpus import words

nltk.download('words')

word_list = words.words() # Fixed assignment operator

def generate_random_word():
    return random.choice(word_list)

print('generating 5 words')
for _ in range(5): # Changed 'in' to '_' for unused loop variable
    print(generate_random_word())
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# generating 5 words
# tornese
# bract
# weam
# bastionary
# bismutite
